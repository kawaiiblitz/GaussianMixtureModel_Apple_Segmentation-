# %% [markdown]
# # practicalMixGaussB
#
# The goal of this part of the lab is to fit a mixture of gaussians model to some one-dimensional data. To do this, we will first generate some data from a known mixture of gaussians model and fit our own mixture of gaussians model to the generated data. The parameters from our estimated mixture of gaussians model should roughly match those of the original known model.
#
# You should use this template for your code and fill in the missing
# sections marked "TO DO."
#
# PLEASE NOTE (again): You should NOT be using functions like multivariate_normal.pdf and normfit or any other numpy functions for fitting your distributions in this or further parts of this practical. Optionally, you can try comparing your results to those produced by those functions, but our goal here is to learn what is happening!

# %%
import os 
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as spio
from scipy.stats import norm 
import time

# %matplotlib notebook

# %% [markdown]
# ## Construct Ground Truth Mixture of Gaussians Model and Plot Some Points
#
# Define some true parameters for our grounf truth mixture of $k$ Gaussians model. We will represent the mixtures of Gaussians as a python dictionary. Not that we are working in one dimension, but if we were to require $d$ dimenisions, the mean field would be a $d \times k$ matrix and the cov field would be a $d \times d \times k$ matrix.

# %%
mixGaussTrue = dict()
mixGaussTrue['k'] = 2 # number of gaussians
mixGaussTrue['d'] = 1 # dimension of the data
mixGaussTrue['weight'] = np.array([0.3, 0.7]) # weight assigned to each gaussian
mixGaussTrue['mean'] = np.array([[-1,1.5]]) # the mean for each gaussian 
mixGaussTrue['cov'] = np.reshape([0.5, 0.25], newshape=(1,1,2)) # the covariance for each gaussian

# %% [markdown]
# **getGaussProb**, **sampleFromDiscrete**, and **drawEMData1d** are helper functions.

# %%
# subroutine to return gaussian probabilities
def getGaussProb(x,mean,var):   
    """
    Returns the likelihood that each data point in x belongs to the Gaussian described by mean and 
    var.
    
    Keyword arguments:
    x -- 1 by n vector of data points. n is the number of data points.
    mean -- scalar containing the mean parameter of the Gaussian distribution.
    var -- scalar containing the variance parameter of the Gaussian distribution.
    
    Returns: 
    prob -- scalar contianing the likelihood that each data point in data belongs to the Gaussian 
    distribution defined by mean and var.
    """
    mean = np.squeeze(mean)                                        
    var = np.squeeze(var)                                          
    prob = np.exp(-0.5*((x-mean)**2)/(var))                        
    prob = prob/ np.sqrt(2*np.pi*var)                              
    return prob

# %%
def sampleFromDiscrete(probDist): 
    """
    Draws a random sample from a discrete probability distribution using a rejection sampling method.  
    
    Keyword arguments:
    probDist -- discrete probability ditrubtion to sample from.
    
    Returns: 
    r -- sampled point.
    """

    nIndex = len(probDist)                                                                 
    while True:                                                                            
        #choose random index                                                               
        r=int(np.floor(np.random.uniform()*nIndex))                                        
        #choose random height                                                              
        randHeight = np.random.uniform()                                                   
        #if height is less than probability value at this point in the                     
        # histogram then select                                                            
        if randHeight<probDist[r]:                                                         
            break                                                                          
    return r

# %%
def drawEMData1d(data, mixGauss):
    """
    Draw the data, data, in histogram form and plot the mixtures of Gaussian model, mixGauss, on top of it.
    
    Keyword arguments:
    data -- 1 by n vector of data points.
    mixGauss -- dict with mixture of gaussian information.

    """
    # delete previous plot if it exists                                                                   
    # hold off;                                                                                           
    # bin the data to make a histogram                                                                    
                                                                                                          
    binWidth = 0.1;                                                                                       
    binMin = -4.0;                                                                                        
    binMax = 4.0;                                                                                         
    nSteps = int(np.ceil((binMax - binMin) / binWidth))                                                   
                                                                                                          
    nDims, nData = data.shape                                                                             
                                                                                                          
    xHist = np.linspace(binMin, binMax, nSteps, endpoint=True)                                            
    xHistExt = np.append(xHist, np.inf)                                                                   
    yHist, _ = np.histogram(data, xHistExt)                                     
                                                                                                          
    yHist = yHist / (nData * binWidth)                                                                    
    plt.cla()                                                                                     
    plt.bar(xHist, yHist, binWidth, edgecolor='b')                                                        
                                                                                                          
    # calculate Gaussian data                                                                             
    nGauss = mixGauss['k']                                                                                
    gaussEnvEst = np.zeros(xHist.shape)                                                                   
    for cGauss in range(nGauss):                                                                          
        # calculate weighted Gaussian values                                                              
        gaussProb = mixGauss['weight'][cGauss] * getGaussProb(xHist, mixGauss['mean'][:,cGauss],          
                                                              mixGauss['cov'][:, :, cGauss])              
        plt.plot(xHist, gaussProb, 'm-')  # weighted components of MoG                                    
        # add to form envelope                                                                            
        gaussEnvEst = gaussEnvEst + gaussProb                                                             
                                                                                                          
    plt.plot(xHist, gaussEnvEst, 'g-')  # final mixture of Gaussians                                      
                                                                                                          
    # tidy up plot                                                                                        
    plt.xlabel('Data Value')                                                                              
    plt.ylabel('Probability Density')                                                                     
    # set(gca,'Box','Off');                                                                               
    # set(gcf,'Color',[1 1 1]);                                                                           
    plt.xlim((binMin, binMax))                                                                            
    plt.ylim((0, max(yHist) * 1.5))                                                                       
                                                                                                          
    return

# %% [markdown]
# **TODO HERE:**
#
# Complete the TO DO in this function before moving on.

# %%
def mixGaussGen1d(mixGauss, nData):  
    """
    Generates data from a one-dimensional mixture of Gaussians model. 
    
    Keyword arguments:
    mixGauss -- dict containing the mixture of gaussians arguments.
    nData -- number of data points to generate.
    
    Returns: 
    data -- 1 by nData, generated data points. 
    """
    
    # create space for output data                                                                               
    data = np.zeros(shape=(1, nData))                                                                            
    # for each data point                                                                                        
    for cData in range(nData):                                                                                   
        # randomly choose Gaussian according to probability distributions                                        
        h = sampleFromDiscrete(mixGauss['weight'])                                                               
        # draw a sample from the appropriate Gaussian distribution                                               
        
        # TO DO (d)- replace this 
        mean = mixGauss['mean'][0, h]
        var = mixGauss['cov'][0, 0, h]
        data[:, cData] = mean + np.random.randn() * np.sqrt(var)
                                                                                                         
    return data

# %% [markdown]
# With all the helper functions complete, we can now generate and plot some points from our model. The blue bars are the histogram of the generated points. The green curve is what the complete mixture of gaussians model looks like. The pink curves are the component gaussians.

# %%
# %matplotlib inline

# define number of samples to generate
nData = 400;

#generate data from the mixture of Gaussians
#make sure you've filled out the todo above! 
data = mixGaussGen1d(mixGaussTrue,nData)

#plot! 
fig,ax = plt.subplots(1,1)
drawEMData1d(data,mixGaussTrue)

# %% [markdown]
# The histogram shows the data point distribution with the individual Gaussian components in pink and the complete mixture in green, indicating the full mixture model, weighted by their respective weights. There is a reasonable estimation of the components that reflects the underlying data distribution. Although there are some histogram peaks do not align, suggesting a need for refining the initial parameters, which were generated with a random component and certain considerations. Let's see how parameter adjustments fare with the EM algorithm iterations.

# %% [markdown]
# ## Estimate MoG using the E-M Algorithm
# Here we want to use the E-M algorithm to fit a MoG model to our data points.
#
# **TODO HERE:**
#
# Fill out the missing parts below.

# %%
def getMixGaussBound(data, mixGaussEst, responsibilities):                                                  
    """
    Calculate the bound on the log likelihood for the whole data set under a mixture of Gaussians model.  
    
    Keyword arguments:
    data -- d by n matrix containing data points.
    mixGaussEst -- dict containing the mixture of gaussians parameters.
    responsibilities -- k by n vector containing the responsibility of this data point for each Gaussian. 
    
    Returns: 
    bound -- scalar containing the bound on the log likelihood.
    
    """
    # find total number of data items                                                                       
    nDims, nData = data.shape                                                                               
                                                                                                            
    # initialize bound                                                                                      
    bound = 0                                                                                               
    
    #<delete>
    #curCov = mixGaussEst['cov']                                                                             
    #curWeight = mixGaussEst['weight']                                                                       
    #curMean = mixGaussEst['mean']                                                                           
    #</delete>
        
    # run through each data item                                                                            
    for cData in range(nData):
        # extract this data
        thisData = data[:, cData]
        # extract this q(h)
        thisQ = responsibilities[:, cData]

        # TO DO - calculate contribution to bound of this datapoint
        boundValue = 0

        for k in range(len(mixGaussEst['weight'])):
            cWeight = mixGaussEst['weight'][k]
            cMean   = mixGaussEst['mean'][:,k]
            cCov    = mixGaussEst['cov'][: ,: ,k]
            gaussProb = cWeight * getGaussProb(thisData, cMean, cCov)
            boundValue += thisQ[k] * np.log(gaussProb / thisQ[k])

        # add to total log likelihood
        bound += boundValue

    return np.array(bound).item()

# %% [markdown]
# **TODO HERE:**
#
# Fill out the missing parts below.
#
# The log likelihood is taken since the raw likelihood value could be too small for our machine's percision.

# %%
def getMixGaussLogLike(data, mixGaussEst):
    """
    Calculate the log likelihood for the whole dataset under a mixture of Gaussians model.
    
    Keyword arguments:
    data -- d by n matrix containing data points.
    mixGaussEst -- dict containing the mixture of gaussians parameters.

    Returns: 
    logLike -- scalar containing the log likelihood.
    
    """
    data = np.atleast_2d(data)                                                                         
    # find total number of data items                                                                  
    nDims, nData = data.shape                                                                          
    
    # initialize log likelihoods                                                                       
    logLike = 0;                                                                                       
                                                                                                       
    # run through each data item                                                                       
    for cData in range(nData):                                                                         
        thisData = data[:, cData]    
        
        # TO DO (e) - calculate likelihood of this data point under mixture of                         
        # Gaussians model.                                                              
        like = 0
        for cGauss in range(mixGaussEst['k']):
            mean = mixGaussEst['mean'][:, cGauss]
            cov = mixGaussEst['cov'][:, :, cGauss]
            weight = mixGaussEst['weight'][cGauss]
            
            # Calculate the Gaussian probability for this data point
            prob = weight * getGaussProb(thisData, mean, cov)
            like += prob
                                                                                                       
        # add to total log like of this datapoint to the total                                                                       
        logLike = logLike + np.log(like)                                                               
                                                                                                       
    return  np.array(logLike).item()

# %% [markdown]
# **TODO HERE:**
#
# Fill out the missing parts below.

# %%
def fitMixGauss1d(data, k):   
    """
    Estimate a k MoG model that would fit the data. Incremently plots the outcome.
               
    
    Keyword arguments:
    data -- d by n matrix containing data points.
    k -- scalar representing the number of gaussians to use in the MoG model.
    
    Returns: 
    mixGaussEst -- dict containing the estimated MoG parameters.
    
    """
    #     MAIN E-M ROUTINE  
    #     In the E-M algorithm, we calculate a complete posterior distribution over                                  
    #     the (nData) hidden variables in the E-Step.  
    #     In the M-Step, we update the parameters of the Gaussians (mean, cov, w).   
    
    nDims, nData = data.shape                                                                                        
                                                                                                                     
                                                                                                      
    responsibilities = np.zeros(shape=(k, nData))                                                                    
                                                                                                                     
    # we will initialize the values to random values                                                                 
    mixGaussEst = dict()                                                                                             
    mixGaussEst['d'] = 1                                                                                             
    mixGaussEst['k'] = k                                                                                             
    mixGaussEst['weight'] = (1 / k) * np.ones(shape=(k))                                                             
    mixGaussEst['mean'] = 2 * np.random.randn(1, k)                                                                  
    mixGaussEst['cov'] = 0.1 + 1.5*np.random.uniform(size=(1,1,2))                                                   
                                                                                                                     
    # calculate current likelihood                                                                                   
    # TO DO - fill in this routine                                                                                   
    logLike = getMixGaussLogLike(data, mixGaussEst)                                                                  
    print('Log Likelihood Iter 0 : {:4.3f}\n'.format(logLike))                                                       
                                                                                                                     
    nIter = 20;   # We can put more or less number of iterations                                                                                                   
                                                                                                                     
    logLikeVec = np.zeros(shape=(2 * nIter))                                                                         
    boundVec = np.zeros(shape=(2 * nIter)) 
    
    fig,ax = plt.subplots(1,1)
                                                                                                                     
    for cIter in range(nIter):                                                                                       
                                                                                                                     
        # ===================== =====================                                                                
        # Expectation step                                                                                           
        # ===================== =====================                                                                
        curCov = mixGaussEst['cov']                                                                                  
        curWeight = mixGaussEst['weight']                                                                            
        curMean = mixGaussEst['mean']  

        for cData in range(nData):           
            
            # TO DO: fill in column of 'hidden' - caculate posterior probability that                                
            # this data point came from each of the Gaussians                                                        
            # replace this:                                                                                          
            responsibilities[:, cData] = np.zeros(k)  # Initialize responsibilities
            
            for cGauss in range(k):
                # Calculate posterior probability for each data point
                responsibilities[cGauss, cData] = curWeight[cGauss] * getGaussProb(data[:, cData], curMean[:, cGauss], curCov[:, :, cGauss])
            
            responsibilities[:, cData] /= np.sum(responsibilities[:, cData])  # Normalize responsibilities
        
        logLike = getMixGaussLogLike(data, mixGaussEst)
        print('Log Likelihood After E-Step Iter {} : {:4.3f}\n'.format(cIter, logLike))
        
        bound = getMixGaussBound(data, mixGaussEst, responsibilities)
        print('Bound After E-Step Iter {} : {:4.3f}\n'.format(cIter, bound))
        
        logLikeVec[2 * cIter] = logLike
        boundVec[2 * cIter] = bound

        # ===================== =====================                                                                
        # Maximization Step                                                                                          
        # ===================== =====================                                                                
        # for each constituent Gaussian                                                                              
        for cGauss in range(k):                                                                                      
            # TO DO:  Update weighting parameters mixGauss.weight based on the total                                 
            # posterior probability associated with each Gaussian. Replace this:                                         
            mixGaussEst['weight'][cGauss] = np.sum(responsibilities[cGauss, :]) / nData
                                                                                                                         
            # TO DO:  Update mean parameters mixGauss.mean by weighted average                                       
            # where weights are given by posterior probability associated with                                       
            # Gaussian.  Replace this:                                    
            mixGaussEst['mean'][:, cGauss] = np.sum(responsibilities[cGauss, :] * data) / np.sum(responsibilities[cGauss, :])
            
            
            # TO DO:  Update covarance parameter based on weighted average of                                        
            # square distance from update mean, where weights are given by                                           
            # posterior probability associated with Gaussian                                                         
            mixGaussEst['cov'][:, :, cGauss] = np.sum(responsibilities[cGauss, :] * (data - curMean[:, cGauss]) ** 2) / np.sum(responsibilities[cGauss, :])
            
                                                                                                                     
        # draw the new solution  
        drawEMData1d(data, mixGaussEst)
        time.sleep(0.7)
        fig.canvas.draw()
                                                                                                                     
        # calculate the log likelihood                                                                               
        logLike = getMixGaussLogLike(data, mixGaussEst)                                                              
        print('Log Likelihood After M-Step Iter {} : {:4.3f}\n'.format(cIter, logLike))                              
                                                                                                                     
        # calculate the bound                                                                                        
        bound = getMixGaussBound(data, mixGaussEst, responsibilities)                                                
        print('Bound After M-Step Iter {} : {:4.3f}\n'.format(cIter, bound)) 
                                                                                                                  
        logLikeVec[2 * cIter + 1] = logLike                                                                          
        boundVec[2 * cIter + 1] = bound                                                                              
                                                                                                                     
    plt.figure()                                                                                                     
    plt.plot(logLikeVec, 'g',label='log likelihood')                                                                                        
    plt.plot(boundVec, 'r',label='lower bound')  
    plt.legend()
                                                                                                                     
    return mixGaussEst

# %% [markdown]
# ### Time to put it all together!
#
# Make sure you've filled all the TO DOs above!

# %% [markdown]
# Let´s see how it changes with the number of iterations
# ### Five iterations

# %%
# %matplotlib inline

#generate data from the ground truth mixture of Gaussians we've defined way above. 
#make sure you've completed this routine above.
data = mixGaussGen1d(mixGaussTrue,nData);

#draw data, ground truth mixture of Gaussians.
drawEMData1d(data,mixGaussTrue)

#define number of components to estimate
nGaussEst = 2;

#fit mixture of Gaussians (Pretend someone handed you some data. Now what?)
#Make sure you've completed this routine above.
mixGaussEst = fitMixGauss1d(data,nGaussEst);
# Out:
# Log Likelihood Iter 0 : -949.933
#
# Log Likelihood After E-Step Iter 0 : -949.933
#
# Bound After E-Step Iter 0 : -949.933
# C:\Users\rache\AppData\Local\Temp\ipykernel_31416\2824212454.py:62: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   responsibilities[cGauss, cData] = curWeight[cGauss] * getGaussProb(data[:, cData], curMean[:, cGauss], curCov[:, :, cGauss])
# Log Likelihood After M-Step Iter 0 : -662.166
#
# Bound After M-Step Iter 0 : -675.516
#
# Log Likelihood After E-Step Iter 1 : -662.166
#
# Bound After E-Step Iter 1 : -662.166
#
# Log Likelihood After M-Step Iter 1 : -643.542
#
# Bound After M-Step Iter 1 : -652.243
#
# Log Likelihood After E-Step Iter 2 : -643.542
#
# Bound After E-Step Iter 2 : -643.542
#
# Log Likelihood After M-Step Iter 2 : -630.108
#
# Bound After M-Step Iter 2 : -636.196
#
# Log Likelihood After E-Step Iter 3 : -630.108
#
# Bound After E-Step Iter 3 : -630.108
#
# Log Likelihood After M-Step Iter 3 : -621.776
#
# Bound After M-Step Iter 3 : -625.392
#
# Log Likelihood After E-Step Iter 4 : -621.776
#
# Bound After E-Step Iter 4 : -621.776
#
# Log Likelihood After M-Step Iter 4 : -616.822
#
# Bound After M-Step Iter 4 : -619.010

# %% [markdown]
# ### 80 Iterations

# %%
# %matplotlib inline

#generate data from the ground truth mixture of Gaussians we've defined way above. 
#make sure you've completed this routine above.
data = mixGaussGen1d(mixGaussTrue,nData);

#draw data, ground truth mixture of Gaussians.
drawEMData1d(data,mixGaussTrue)

#define number of components to estimate
nGaussEst = 2;

#fit mixture of Gaussians (Pretend someone handed you some data. Now what?)
#Make sure you've completed this routine above.
mixGaussEst = fitMixGauss1d(data,nGaussEst);
# Out:
# Log Likelihood Iter 0 : -1947.056
#
# Log Likelihood After E-Step Iter 0 : -1947.056
#
# Bound After E-Step Iter 0 : -1947.056
# C:\Users\rache\AppData\Local\Temp\ipykernel_31416\1958034451.py:62: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   responsibilities[cGauss, cData] = curWeight[cGauss] * getGaussProb(data[:, cData], curMean[:, cGauss], curCov[:, :, cGauss])
# Log Likelihood After M-Step Iter 0 : -665.242
#
# Bound After M-Step Iter 0 : -684.624
#
# Log Likelihood After E-Step Iter 1 : -665.242
#
# Bound After E-Step Iter 1 : -665.242
#
# Log Likelihood After M-Step Iter 1 : -647.410
#
# Bound After M-Step Iter 1 : -655.135
#
# Log Likelihood After E-Step Iter 2 : -647.410
#
# Bound After E-Step Iter 2 : -647.410
#
# Log Likelihood After M-Step Iter 2 : -623.787
#
# Bound After M-Step Iter 2 : -636.529
#
# Log Likelihood After E-Step Iter 3 : -623.787
#
# Bound After E-Step Iter 3 : -623.787
#
# Log Likelihood After M-Step Iter 3 : -585.668
#
# Bound After M-Step Iter 3 : -603.662
#
# Log Likelihood After E-Step Iter 4 : -585.668
#
# Bound After E-Step Iter 4 : -585.668
#
# Log Likelihood After M-Step Iter 4 : -556.816
#
# Bound After M-Step Iter 4 : -566.267
#
# Log Likelihood After E-Step Iter 5 : -556.816
#
# Bound After E-Step Iter 5 : -556.816
#
# Log Likelihood After M-Step Iter 5 : -548.956
#
# Bound After M-Step Iter 5 : -551.403
#
# Log Likelihood After E-Step Iter 6 : -548.956
#
# Bound After E-Step Iter 6 : -548.956
#
# Log Likelihood After M-Step Iter 6 : -545.910
#
# Bound After M-Step Iter 6 : -547.196
#
# Log Likelihood After E-Step Iter 7 : -545.910
#
# Bound After E-Step Iter 7 : -545.910
#
# Log Likelihood After M-Step Iter 7 : -543.717
#
# Bound After M-Step Iter 7 : -544.699
#
# Log Likelihood After E-Step Iter 8 : -543.717
#
# Bound After E-Step Iter 8 : -543.717
#
# Log Likelihood After M-Step Iter 8 : -542.166
#
# Bound After M-Step Iter 8 : -542.835
#
# Log Likelihood After E-Step Iter 9 : -542.166
#
# Bound After E-Step Iter 9 : -542.166
#
# Log Likelihood After M-Step Iter 9 : -541.259
#
# Bound After M-Step Iter 9 : -541.629
#
# Log Likelihood After E-Step Iter 10 : -541.259
#
# Bound After E-Step Iter 10 : -541.259
#
# Log Likelihood After M-Step Iter 10 : -540.827
#
# Bound After M-Step Iter 10 : -540.995
#
# Log Likelihood After E-Step Iter 11 : -540.827
#
# Bound After E-Step Iter 11 : -540.827
#
# Log Likelihood After M-Step Iter 11 : -540.653
#
# Bound After M-Step Iter 11 : -540.719
#
# Log Likelihood After E-Step Iter 12 : -540.653
#
# Bound After E-Step Iter 12 : -540.653
#
# Log Likelihood After M-Step Iter 12 : -540.591
#
# Bound After M-Step Iter 12 : -540.614
#
# Log Likelihood After E-Step Iter 13 : -540.591
#
# Bound After E-Step Iter 13 : -540.591
#
# Log Likelihood After M-Step Iter 13 : -540.570
#
# Bound After M-Step Iter 13 : -540.578
#
# Log Likelihood After E-Step Iter 14 : -540.570
#
# Bound After E-Step Iter 14 : -540.570
#
# Log Likelihood After M-Step Iter 14 : -540.563
#
# Bound After M-Step Iter 14 : -540.566
#
# Log Likelihood After E-Step Iter 15 : -540.563
#
# Bound After E-Step Iter 15 : -540.563
#
# Log Likelihood After M-Step Iter 15 : -540.561
#
# Bound After M-Step Iter 15 : -540.562
#
# Log Likelihood After E-Step Iter 16 : -540.561
#
# Bound After E-Step Iter 16 : -540.561
#
# Log Likelihood After M-Step Iter 16 : -540.560
#
# Bound After M-Step Iter 16 : -540.560
#
# Log Likelihood After E-Step Iter 17 : -540.560
#
# Bound After E-Step Iter 17 : -540.560
#
# Log Likelihood After M-Step Iter 17 : -540.560
#
# Bound After M-Step Iter 17 : -540.560
#
# Log Likelihood After E-Step Iter 18 : -540.560
#
# Bound After E-Step Iter 18 : -540.560
#
# Log Likelihood After M-Step Iter 18 : -540.560
#
# Bound After M-Step Iter 18 : -540.560
#
# Log Likelihood After E-Step Iter 19 : -540.560
#
# Bound After E-Step Iter 19 : -540.560
#
# Log Likelihood After M-Step Iter 19 : -540.560
#
# Bound After M-Step Iter 19 : -540.560
#
# Log Likelihood After E-Step Iter 20 : -540.560
#
# Bound After E-Step Iter 20 : -540.560
#
# Log Likelihood After M-Step Iter 20 : -540.560
#
# Bound After M-Step Iter 20 : -540.560
#
# Log Likelihood After E-Step Iter 21 : -540.560
#
# Bound After E-Step Iter 21 : -540.560
#
# Log Likelihood After M-Step Iter 21 : -540.560
#
# Bound After M-Step Iter 21 : -540.560
#
# Log Likelihood After E-Step Iter 22 : -540.560
#
# Bound After E-Step Iter 22 : -540.560
#
# Log Likelihood After M-Step Iter 22 : -540.560
#
# Bound After M-Step Iter 22 : -540.560
#
# Log Likelihood After E-Step Iter 23 : -540.560
#
# Bound After E-Step Iter 23 : -540.560
#
# Log Likelihood After M-Step Iter 23 : -540.560
#
# Bound After M-Step Iter 23 : -540.560
#
# Log Likelihood After E-Step Iter 24 : -540.560
#
# Bound After E-Step Iter 24 : -540.560
#
# Log Likelihood After M-Step Iter 24 : -540.560
#
# Bound After M-Step Iter 24 : -540.560
#
# Log Likelihood After E-Step Iter 25 : -540.560
#
# Bound After E-Step Iter 25 : -540.560
#
# Log Likelihood After M-Step Iter 25 : -540.560
#
# Bound After M-Step Iter 25 : -540.560
#
# Log Likelihood After E-Step Iter 26 : -540.560
#
# Bound After E-Step Iter 26 : -540.560
#
# Log Likelihood After M-Step Iter 26 : -540.560
#
# Bound After M-Step Iter 26 : -540.560
#
# Log Likelihood After E-Step Iter 27 : -540.560
#
# Bound After E-Step Iter 27 : -540.560
#
# Log Likelihood After M-Step Iter 27 : -540.560
#
# Bound After M-Step Iter 27 : -540.560
#
# Log Likelihood After E-Step Iter 28 : -540.560
#
# Bound After E-Step Iter 28 : -540.560
#
# Log Likelihood After M-Step Iter 28 : -540.560
#
# Bound After M-Step Iter 28 : -540.560
#
# Log Likelihood After E-Step Iter 29 : -540.560
#
# Bound After E-Step Iter 29 : -540.560
#
# Log Likelihood After M-Step Iter 29 : -540.560
#
# Bound After M-Step Iter 29 : -540.560
#
# Log Likelihood After E-Step Iter 30 : -540.560
#
# Bound After E-Step Iter 30 : -540.560
#
# Log Likelihood After M-Step Iter 30 : -540.560
#
# Bound After M-Step Iter 30 : -540.560
#
# Log Likelihood After E-Step Iter 31 : -540.560
#
# Bound After E-Step Iter 31 : -540.560
#
# Log Likelihood After M-Step Iter 31 : -540.560
#
# Bound After M-Step Iter 31 : -540.560
#
# Log Likelihood After E-Step Iter 32 : -540.560
#
# Bound After E-Step Iter 32 : -540.560
#
# Log Likelihood After M-Step Iter 32 : -540.560
#
# Bound After M-Step Iter 32 : -540.560
#
# Log Likelihood After E-Step Iter 33 : -540.560
#
# Bound After E-Step Iter 33 : -540.560
#
# Log Likelihood After M-Step Iter 33 : -540.560
#
# Bound After M-Step Iter 33 : -540.560
#
# Log Likelihood After E-Step Iter 34 : -540.560
#
# Bound After E-Step Iter 34 : -540.560
#
# Log Likelihood After M-Step Iter 34 : -540.560
#
# Bound After M-Step Iter 34 : -540.560
#
# Log Likelihood After E-Step Iter 35 : -540.560
#
# Bound After E-Step Iter 35 : -540.560
#
# Log Likelihood After M-Step Iter 35 : -540.560
#
# Bound After M-Step Iter 35 : -540.560
#
# Log Likelihood After E-Step Iter 36 : -540.560
#
# Bound After E-Step Iter 36 : -540.560
#
# Log Likelihood After M-Step Iter 36 : -540.560
#
# Bound After M-Step Iter 36 : -540.560
#
# Log Likelihood After E-Step Iter 37 : -540.560
#
# Bound After E-Step Iter 37 : -540.560
#
# Log Likelihood After M-Step Iter 37 : -540.560
#
# Bound After M-Step Iter 37 : -540.560
#
# Log Likelihood After E-Step Iter 38 : -540.560
#
# Bound After E-Step Iter 38 : -540.560
#
# Log Likelihood After M-Step Iter 38 : -540.560
#
# Bound After M-Step Iter 38 : -540.560
#
# Log Likelihood After E-Step Iter 39 : -540.560
#
# Bound After E-Step Iter 39 : -540.560
#
# Log Likelihood After M-Step Iter 39 : -540.560
#
# Bound After M-Step Iter 39 : -540.560
#
# Log Likelihood After E-Step Iter 40 : -540.560
#
# Bound After E-Step Iter 40 : -540.560
#
# Log Likelihood After M-Step Iter 40 : -540.560
#
# Bound After M-Step Iter 40 : -540.560
#
# Log Likelihood After E-Step Iter 41 : -540.560
#
# Bound After E-Step Iter 41 : -540.560
#
# Log Likelihood After M-Step Iter 41 : -540.560
#
# Bound After M-Step Iter 41 : -540.560
#
# Log Likelihood After E-Step Iter 42 : -540.560
#
# Bound After E-Step Iter 42 : -540.560
#
# Log Likelihood After M-Step Iter 42 : -540.560
#
# Bound After M-Step Iter 42 : -540.560
#
# Log Likelihood After E-Step Iter 43 : -540.560
#
# Bound After E-Step Iter 43 : -540.560
#
# Log Likelihood After M-Step Iter 43 : -540.560
#
# Bound After M-Step Iter 43 : -540.560
#
# Log Likelihood After E-Step Iter 44 : -540.560
#
# Bound After E-Step Iter 44 : -540.560
#
# Log Likelihood After M-Step Iter 44 : -540.560
#
# Bound After M-Step Iter 44 : -540.560
#
# Log Likelihood After E-Step Iter 45 : -540.560
#
# Bound After E-Step Iter 45 : -540.560
#
# Log Likelihood After M-Step Iter 45 : -540.560
#
# Bound After M-Step Iter 45 : -540.560
#
# Log Likelihood After E-Step Iter 46 : -540.560
#
# Bound After E-Step Iter 46 : -540.560
#
# Log Likelihood After M-Step Iter 46 : -540.560
#
# Bound After M-Step Iter 46 : -540.560
#
# Log Likelihood After E-Step Iter 47 : -540.560
#
# Bound After E-Step Iter 47 : -540.560
#
# Log Likelihood After M-Step Iter 47 : -540.560
#
# Bound After M-Step Iter 47 : -540.560
#
# Log Likelihood After E-Step Iter 48 : -540.560
#
# Bound After E-Step Iter 48 : -540.560
#
# Log Likelihood After M-Step Iter 48 : -540.560
#
# Bound After M-Step Iter 48 : -540.560
#
# Log Likelihood After E-Step Iter 49 : -540.560
#
# Bound After E-Step Iter 49 : -540.560
#
# Log Likelihood After M-Step Iter 49 : -540.560
#
# Bound After M-Step Iter 49 : -540.560
#
# Log Likelihood After E-Step Iter 50 : -540.560
#
# Bound After E-Step Iter 50 : -540.560
#
# Log Likelihood After M-Step Iter 50 : -540.560
#
# Bound After M-Step Iter 50 : -540.560
#
# Log Likelihood After E-Step Iter 51 : -540.560
#
# Bound After E-Step Iter 51 : -540.560
#
# Log Likelihood After M-Step Iter 51 : -540.560
#
# Bound After M-Step Iter 51 : -540.560
#
# Log Likelihood After E-Step Iter 52 : -540.560
#
# Bound After E-Step Iter 52 : -540.560
#
# Log Likelihood After M-Step Iter 52 : -540.560
#
# Bound After M-Step Iter 52 : -540.560
#
# Log Likelihood After E-Step Iter 53 : -540.560
#
# Bound After E-Step Iter 53 : -540.560
#
# Log Likelihood After M-Step Iter 53 : -540.560
#
# Bound After M-Step Iter 53 : -540.560
#
# Log Likelihood After E-Step Iter 54 : -540.560
#
# Bound After E-Step Iter 54 : -540.560
#
# Log Likelihood After M-Step Iter 54 : -540.560
#
# Bound After M-Step Iter 54 : -540.560
#
# Log Likelihood After E-Step Iter 55 : -540.560
#
# Bound After E-Step Iter 55 : -540.560
#
# Log Likelihood After M-Step Iter 55 : -540.560
#
# Bound After M-Step Iter 55 : -540.560
#
# Log Likelihood After E-Step Iter 56 : -540.560
#
# Bound After E-Step Iter 56 : -540.560
#
# Log Likelihood After M-Step Iter 56 : -540.560
#
# Bound After M-Step Iter 56 : -540.560
#
# Log Likelihood After E-Step Iter 57 : -540.560
#
# Bound After E-Step Iter 57 : -540.560
#
# Log Likelihood After M-Step Iter 57 : -540.560
#
# Bound After M-Step Iter 57 : -540.560
#
# Log Likelihood After E-Step Iter 58 : -540.560
#
# Bound After E-Step Iter 58 : -540.560
#
# Log Likelihood After M-Step Iter 58 : -540.560
#
# Bound After M-Step Iter 58 : -540.560
#
# Log Likelihood After E-Step Iter 59 : -540.560
#
# Bound After E-Step Iter 59 : -540.560
#
# Log Likelihood After M-Step Iter 59 : -540.560
#
# Bound After M-Step Iter 59 : -540.560
#
# Log Likelihood After E-Step Iter 60 : -540.560
#
# Bound After E-Step Iter 60 : -540.560
#
# Log Likelihood After M-Step Iter 60 : -540.560
#
# Bound After M-Step Iter 60 : -540.560
#
# Log Likelihood After E-Step Iter 61 : -540.560
#
# Bound After E-Step Iter 61 : -540.560
#
# Log Likelihood After M-Step Iter 61 : -540.560
#
# Bound After M-Step Iter 61 : -540.560
#
# Log Likelihood After E-Step Iter 62 : -540.560
#
# Bound After E-Step Iter 62 : -540.560
#
# Log Likelihood After M-Step Iter 62 : -540.560
#
# Bound After M-Step Iter 62 : -540.560
#
# Log Likelihood After E-Step Iter 63 : -540.560
#
# Bound After E-Step Iter 63 : -540.560
#
# Log Likelihood After M-Step Iter 63 : -540.560
#
# Bound After M-Step Iter 63 : -540.560
#
# Log Likelihood After E-Step Iter 64 : -540.560
#
# Bound After E-Step Iter 64 : -540.560
#
# Log Likelihood After M-Step Iter 64 : -540.560
#
# Bound After M-Step Iter 64 : -540.560
#
# Log Likelihood After E-Step Iter 65 : -540.560
#
# Bound After E-Step Iter 65 : -540.560
#
# Log Likelihood After M-Step Iter 65 : -540.560
#
# Bound After M-Step Iter 65 : -540.560
#
# Log Likelihood After E-Step Iter 66 : -540.560
#
# Bound After E-Step Iter 66 : -540.560
#
# Log Likelihood After M-Step Iter 66 : -540.560
#
# Bound After M-Step Iter 66 : -540.560
#
# Log Likelihood After E-Step Iter 67 : -540.560
#
# Bound After E-Step Iter 67 : -540.560
#
# Log Likelihood After M-Step Iter 67 : -540.560
#
# Bound After M-Step Iter 67 : -540.560
#
# Log Likelihood After E-Step Iter 68 : -540.560
#
# Bound After E-Step Iter 68 : -540.560
#
# Log Likelihood After M-Step Iter 68 : -540.560
#
# Bound After M-Step Iter 68 : -540.560
#
# Log Likelihood After E-Step Iter 69 : -540.560
#
# Bound After E-Step Iter 69 : -540.560
#
# Log Likelihood After M-Step Iter 69 : -540.560
#
# Bound After M-Step Iter 69 : -540.560
#
# Log Likelihood After E-Step Iter 70 : -540.560
#
# Bound After E-Step Iter 70 : -540.560
#
# Log Likelihood After M-Step Iter 70 : -540.560
#
# Bound After M-Step Iter 70 : -540.560
#
# Log Likelihood After E-Step Iter 71 : -540.560
#
# Bound After E-Step Iter 71 : -540.560
#
# Log Likelihood After M-Step Iter 71 : -540.560
#
# Bound After M-Step Iter 71 : -540.560
#
# Log Likelihood After E-Step Iter 72 : -540.560
#
# Bound After E-Step Iter 72 : -540.560
#
# Log Likelihood After M-Step Iter 72 : -540.560
#
# Bound After M-Step Iter 72 : -540.560
#
# Log Likelihood After E-Step Iter 73 : -540.560
#
# Bound After E-Step Iter 73 : -540.560
#
# Log Likelihood After M-Step Iter 73 : -540.560
#
# Bound After M-Step Iter 73 : -540.560
#
# Log Likelihood After E-Step Iter 74 : -540.560
#
# Bound After E-Step Iter 74 : -540.560
#
# Log Likelihood After M-Step Iter 74 : -540.560
#
# Bound After M-Step Iter 74 : -540.560
#
# Log Likelihood After E-Step Iter 75 : -540.560
#
# Bound After E-Step Iter 75 : -540.560
#
# Log Likelihood After M-Step Iter 75 : -540.560
#
# Bound After M-Step Iter 75 : -540.560
#
# Log Likelihood After E-Step Iter 76 : -540.560
#
# Bound After E-Step Iter 76 : -540.560
#
# Log Likelihood After M-Step Iter 76 : -540.560
#
# Bound After M-Step Iter 76 : -540.560
#
# Log Likelihood After E-Step Iter 77 : -540.560
#
# Bound After E-Step Iter 77 : -540.560
#
# Log Likelihood After M-Step Iter 77 : -540.560
#
# Bound After M-Step Iter 77 : -540.560
#
# Log Likelihood After E-Step Iter 78 : -540.560
#
# Bound After E-Step Iter 78 : -540.560
#
# Log Likelihood After M-Step Iter 78 : -540.560
#
# Bound After M-Step Iter 78 : -540.560
#
# Log Likelihood After E-Step Iter 79 : -540.560
#
# Bound After E-Step Iter 79 : -540.560
#
# Log Likelihood After M-Step Iter 79 : -540.560
#
# Bound After M-Step Iter 79 : -540.560

# %% [markdown]
# ### 20 iterations

# %%
# %matplotlib inline

#generate data from the ground truth mixture of Gaussians we've defined way above. 
#make sure you've completed this routine above.
data = mixGaussGen1d(mixGaussTrue,nData);

#draw data, ground truth mixture of Gaussians.
drawEMData1d(data,mixGaussTrue)

#define number of components to estimate
nGaussEst = 2;

#fit mixture of Gaussians (Pretend someone handed you some data. Now what?)
#Make sure you've completed this routine above.
mixGaussEst = fitMixGauss1d(data,nGaussEst);
# Out:
# Log Likelihood Iter 0 : -875.106
# C:\Users\rache\AppData\Local\Temp\ipykernel_31416\122739646.py:62: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   responsibilities[cGauss, cData] = curWeight[cGauss] * getGaussProb(data[:, cData], curMean[:, cGauss], curCov[:, :, cGauss])
# Log Likelihood After E-Step Iter 0 : -875.106
#
# Bound After E-Step Iter 0 : -875.106
#
# Log Likelihood After M-Step Iter 0 : -637.242
#
# Bound After M-Step Iter 0 : -658.765
#
# Log Likelihood After E-Step Iter 1 : -637.242
#
# Bound After E-Step Iter 1 : -637.242
#
# Log Likelihood After M-Step Iter 1 : -605.387
#
# Bound After M-Step Iter 1 : -622.249
#
# Log Likelihood After E-Step Iter 2 : -605.387
#
# Bound After E-Step Iter 2 : -605.387
#
# Log Likelihood After M-Step Iter 2 : -569.918
#
# Bound After M-Step Iter 2 : -584.146
#
# Log Likelihood After E-Step Iter 3 : -569.918
#
# Bound After E-Step Iter 3 : -569.918
#
# Log Likelihood After M-Step Iter 3 : -551.466
#
# Bound After M-Step Iter 3 : -558.088
#
# Log Likelihood After E-Step Iter 4 : -551.466
#
# Bound After E-Step Iter 4 : -551.466
#
# Log Likelihood After M-Step Iter 4 : -542.090
#
# Bound After M-Step Iter 4 : -546.348
#
# Log Likelihood After E-Step Iter 5 : -542.090
#
# Bound After E-Step Iter 5 : -542.090
#
# Log Likelihood After M-Step Iter 5 : -534.123
#
# Bound After M-Step Iter 5 : -538.058
#
# Log Likelihood After E-Step Iter 6 : -534.123
#
# Bound After E-Step Iter 6 : -534.123
#
# Log Likelihood After M-Step Iter 6 : -527.214
#
# Bound After M-Step Iter 6 : -530.407
#
# Log Likelihood After E-Step Iter 7 : -527.214
#
# Bound After E-Step Iter 7 : -527.214
#
# Log Likelihood After M-Step Iter 7 : -522.718
#
# Bound After M-Step Iter 7 : -524.575
#
# Log Likelihood After E-Step Iter 8 : -522.718
#
# Bound After E-Step Iter 8 : -522.718
#
# Log Likelihood After M-Step Iter 8 : -520.688
#
# Bound After M-Step Iter 8 : -521.457
#
# Log Likelihood After E-Step Iter 9 : -520.688
#
# Bound After E-Step Iter 9 : -520.688
#
# Log Likelihood After M-Step Iter 9 : -519.944
#
# Bound After M-Step Iter 9 : -520.224
#
# Log Likelihood After E-Step Iter 10 : -519.944
#
# Bound After E-Step Iter 10 : -519.944
#
# Log Likelihood After M-Step Iter 10 : -519.669
#
# Bound After M-Step Iter 10 : -519.775
#
# Log Likelihood After E-Step Iter 11 : -519.669
#
# Bound After E-Step Iter 11 : -519.669
#
# Log Likelihood After M-Step Iter 11 : -519.560
#
# Bound After M-Step Iter 11 : -519.603
#
# Log Likelihood After E-Step Iter 12 : -519.560
#
# Bound After E-Step Iter 12 : -519.560
#
# Log Likelihood After M-Step Iter 12 : -519.513
#
# Bound After M-Step Iter 12 : -519.532
#
# Log Likelihood After E-Step Iter 13 : -519.513
#
# Bound After E-Step Iter 13 : -519.513
#
# Log Likelihood After M-Step Iter 13 : -519.492
#
# Bound After M-Step Iter 13 : -519.501
#
# Log Likelihood After E-Step Iter 14 : -519.492
#
# Bound After E-Step Iter 14 : -519.492
#
# Log Likelihood After M-Step Iter 14 : -519.483
#
# Bound After M-Step Iter 14 : -519.486
#
# Log Likelihood After E-Step Iter 15 : -519.483
#
# Bound After E-Step Iter 15 : -519.483
#
# Log Likelihood After M-Step Iter 15 : -519.478
#
# Bound After M-Step Iter 15 : -519.480
#
# Log Likelihood After E-Step Iter 16 : -519.478
#
# Bound After E-Step Iter 16 : -519.478
#
# Log Likelihood After M-Step Iter 16 : -519.476
#
# Bound After M-Step Iter 16 : -519.477
#
# Log Likelihood After E-Step Iter 17 : -519.476
#
# Bound After E-Step Iter 17 : -519.476
#
# Log Likelihood After M-Step Iter 17 : -519.475
#
# Bound After M-Step Iter 17 : -519.475
#
# Log Likelihood After E-Step Iter 18 : -519.475
#
# Bound After E-Step Iter 18 : -519.475
#
# Log Likelihood After M-Step Iter 18 : -519.475
#
# Bound After M-Step Iter 18 : -519.475
#
# Log Likelihood After E-Step Iter 19 : -519.475
#
# Bound After E-Step Iter 19 : -519.475
#
# Log Likelihood After M-Step Iter 19 : -519.474
#
# Bound After M-Step Iter 19 : -519.474

# %% [markdown]
# After just five iterations of the EM algorithm, we begin to see signs of the model aligning with the data. But the pink curves --representing the individual Gaussian components-- are not yet perfectly fitting the histogram's peaks. As the log likelihood should increase with each iteration, reflecting a better fit, its closeness to the lower bound suggests further iterations could enhance the alignment.
#
# After 20 iterations, convergence is more noticeable, and by 80 iterations, we see minor improvements at the expense of increased computation time. Therefore, identifying an optimal number of iterations is key, as more extensive data could prolong the process. Finally, applying the EM algorithm has proven effective, as the Gaussian model now more closely resembles our data and captures the histogram's peaks.
